# %% [markdown]
# # Main objective of the project is to find the relation of horsepower and MPG of the car
# >* Horsepower is a measure of the power of an engine. It is often used to compare the performance of different cars, especially their speed and acceleration. The higher the horsepower, the more work the engine can do in a given time.
# >* MPG stands for miles per gallon and is used to show how far your car can travel for every gallon (or 4.55 litres) of fuel it uses. The higher the MPG, the more fuel-efficient the car is. MPG is often used to compare the performance and environmental impact of different cars.
# >* The relationship between mpg and horsepower is negative. This means that the more horsepower an automobile has, the less fuel-efficient it is. Now, let us verify it.

# %%
#First we import various libraries for the easiness of the project
import pandas as pd # it allows to modify the data freely
import numpy as np #mathematical calculation like converting the given data to matrix
import matplotlib.pyplot as plt #it allows for data visualization like creating graph
# %matplotlib inline
import seaborn as sns #for data visualtization

# %%
#for reading the data file of the project
df=pd.read_csv('cars.csv')

# %%
df.head(150)#this code gives the data
# Out:
#                           name  mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu   18          8         307.0       130.0
# 1            buick skylark 320   15          8         350.0       165.0
# 2           plymouth satellite   18          8         318.0       150.0
# 3                amc rebel sst   16          8         304.0       150.0
# 4                  ford torino   17          8         302.0       140.0
# ..                         ...  ...        ...           ...         ...
# 144              toyota corona   31          4          76.0        52.0
# 145                 datsun 710   32          4          83.0        61.0
# 146                 dodge colt   28          4          90.0        75.0
# 147                   fiat 128   24          4          90.0        75.0
# 148                fiat 124 tc   26          4         116.0        75.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
#to find the mean, median, mode or for the statistical view of the code
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  149.000000  149.000000    149.000000  147.000000   149.000000
# mean    19.114094    6.040268    233.244966  122.136054  3220.966443
# std      5.922392    1.833912    120.996686   46.458796   976.317041
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     14.000000    4.000000    113.000000   88.000000  2288.000000
# 50%     18.000000    6.000000    232.000000  105.000000  3102.000000
# 75%     24.000000    8.000000    350.000000  151.500000  4135.000000
# max     35.000000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    149.000000  149.000000
# mean      14.674497   72.013423
# std        2.913115    1.375395
# min        8.000000   70.000000
# 25%       12.500000   71.000000
# 50%       14.500000   72.000000
# 75%       16.500000   73.000000
# max       23.500000   74.000000

# %% [markdown]
# #  Car information
# ### MPG
# >* Maximum is 35
# >* Average is 19
# >* Minimum is 9
# ### Horsepower
# >* Maximum is 230
# >* Average is 122
# >* Minimum is 46

# %%
df.info()#to check the information of the given dataset such as total memory, total string values and total integer values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          149 non-null    object
#  1   mpg           149 non-null    int64
#  2   cylinders     149 non-null    int64
#  3   displacement  149 non-null    float64
#  4   horsepower    147 non-null    float64
#  5   weight        149 non-null    int64
#  6   acceleration  149 non-null    float64
#  7   model_year    149 non-null    int64
#  8   origin        149 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 10.6+ KB

# %% [markdown]
# # notes from data.info()
# * 0 does not count as null value
# * int64 means the the data has total space of 64 bytes
# * in dtype feature, we have to convert the string data given by user to 0 and 1 so that the machine can understand
# * total memory of 10.6kb

# %% [markdown]
# ### now we use the mean manupulation method so that we can replace null values with mean value
# #### Mean manupulation method refers to the method in which we replace the null value with mean value

# %%
#inspecting the null values in the dataset
#print(df.isnull().values.sum())
print(df.isnull().values.sum())

#replace the ' 's with NaN
df = df.replace(" ",np.NaN)
#df=df.replace(" ",np.NaN)
#impute the missing values with mean imputation
df=df.fillna(df.mean())
#count the numbers again for verification
print(df.isnull().values.sum())
# Out:
# 2
# 0
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10748\3460512506.py:9: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
#seaborn histogram
sns.displot(data=df, x="mpg", kind="hist")
#add labels
plt.title('MGP VS COUNT')
plt.xlabel('MPG')
# Out:
# Text(0.5, 9.444444444444438, 'MPG')

# %% [markdown]
# # Interpretation
#
# >* Here MPG of the car data is shown in x axis whereas the count is shown in y axis.
# >* From the surveyed data most of the car have MPG around 10 to 15 and only few cars have MPG around 30 to 35.

# %%
#seaborn histogram
sns.displot(data=df, x="horsepower", kind="kde")
#add labels
plt.title('HORSEPOWER VS COUNT')
plt.xlabel('HORSEPOWER')
# Out:
# Text(0.5, 9.444444444444438, 'HORSEPOWER')

# %% [markdown]
# # Interpretation
#
# >* Here horsepower of the car data is shown in x axis whereas the count is shown in y axis.
# >* From the surveyed data, most of the car have horsepower around 75 to 100 and only few cars have horsepower around 175 to 200.

# %%
sns.barplot(data=df, x="mpg", y="horsepower")
plt.title('Horsepower vs mpg ')
plt.show()

# %% [markdown]
# # Intrepretation
# >* The given chart shows the relationship between horsepower and mpg of the car
# >* Cars which has low mpg give the highest horsepower whereas the cars having highest mpg give lowest horsepower

# %%
sns.scatterplot(data=df, x="mpg", y="horsepower")
plt.title('Horsepower vs mpg ')
# Out:
# Text(0.5, 1.0, 'Horsepower vs mpg ')

# %% [markdown]
# # Intrepretation
# >* From this graph, we can say that most of the cars have mpg around 10 to 25 providing horsepower around 75 to 200
# >* The higher the mpg the lower the horsepower

# %%
sns.lineplot(data=df,x="mpg",y="horsepower")
plt.title("Linegraph of mpg vs horswpower")
# Out:
# Text(0.5, 1.0, 'Linegraph of mpg vs horswpower')

# %% [markdown]
# # Intrepretation
# >* The given chart shows the relationship between horsepower and mpg of the car
# >* Cars which has low mpg give the highest horsepower whereas the cars having highest mpg give lowest horsepower

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10748\755984844.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features', size = 15)
colormap = sns.diverging_palette(10, 220, as_cmap = True)
sns.heatmap(df.corr(),
            cmap = colormap,
            square = True,
            annot = True,
            linewidths=0.1,vmax=1.0, linecolor='white',
            annot_kws={'fontsize':20 })
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10748\1626100259.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),

# %% [markdown]
# # Intrepretation of the chart
# > Cars which has low mpg give the highest horsepower whereas the cars having highest mpg give lowest horsepower
